# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Columns: 302 entries, id to 299
# dtypes: float64(301), int64(1)
# memory usage: 589.9 KB

# %%
df.target.describe()
# Out:
# count    250.000000
# mean       0.640000
# std        0.480963
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
df.iloc[:,:10].describe()
# Out:
#                id      target           0           1           2           3  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean   124.500000    0.640000    0.023292   -0.026872    0.167404    0.001904
# std     72.312977    0.480963    0.998354    1.009314    1.021709    1.011751
# min      0.000000    0.000000   -2.319000   -2.931000   -2.477000   -2.359000
# 25%     62.250000    0.000000   -0.644750   -0.739750   -0.425250   -0.686500
# 50%    124.500000    1.000000   -0.015500    0.057000    0.184000   -0.016500
# 75%    186.750000    1.000000    0.677000    0.620750    0.805000    0.720000
# max    249.000000    1.000000    2.567000    2.419000    3.392000    2.771000
#
#                 4           5           6           7
# count  250.000000  250.000000  250.000000  250.000000
# mean     0.001588   -0.007304    0.032052    0.078412
# std      1.035411    0.955700    1.006657    0.939731
# min     -2.566000   -2.845000   -2.976000   -3.444000
# 25%     -0.659000   -0.643750   -0.675000   -0.550750
# 50%     -0.023000    0.037500    0.060500    0.183500
# 75%      0.735000    0.660500    0.783250    0.766250
# max      2.901000    2.793000    2.546000    2.846000

# %%
df.iloc[:,10:20].describe()
# Out:
#                 8           9          10          11          12          13  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean    -0.036920    0.035448   -0.005032    0.110248    0.019808   -0.001108
# std      0.963688    1.019689    1.085089    1.036265    1.050041    1.024305
# min     -2.768000   -2.361000   -3.302000   -2.851000   -2.681000   -2.596000
# 25%     -0.689500   -0.643500   -0.693500   -0.524000   -0.708500   -0.692000
# 50%     -0.012500    0.052000    0.066000    0.115500    0.090000    0.016000
# 75%      0.635000    0.733000    0.694250    0.786250    0.805250    0.654000
# max      2.512000    2.959000    3.271000    2.998000    2.729000    2.651000
#
#                14          15          16          17
# count  250.000000  250.000000  250.000000  250.000000
# mean    -0.016280   -0.039644    0.017260   -0.106856
# std      0.926789    0.955915    1.025655    1.012777
# min     -3.275000   -3.512000   -2.476000   -3.619000
# 25%     -0.677000   -0.634500   -0.683500   -0.801500
# 50%      0.009500    0.010000   -0.119000   -0.164500
# 75%      0.611000    0.578000    0.699000    0.496500
# max      2.913000    2.508000    3.286000    2.430000

# %%
df.iloc[:,20:30].describe()
# Out:
#                18          19          20          21          22          23  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean     0.036184   -0.043296   -0.110832    0.072680    0.017296   -0.030728
# std      0.945099    1.055935    1.003178    1.039556    0.988482    0.945902
# min     -2.428000   -3.229000   -3.024000   -2.775000   -2.962000   -2.490000
# 25%     -0.574250   -0.758000   -0.870500   -0.596000   -0.725750   -0.652000
# 50%     -0.009500   -0.018000   -0.161500    0.048000    0.135000   -0.016000
# 75%      0.686000    0.698000    0.560500    0.797000    0.631500    0.619250
# max      2.557000    2.868000    2.703000    2.691000    2.604000    2.362000
#
#                24          25          26          27
# count  250.000000  250.000000  250.000000  250.000000
# mean    -0.128252    0.154736    0.083408    0.039552
# std      0.997026    0.997894    1.040371    0.922270
# min     -3.107000   -2.943000   -2.933000   -2.942000
# 25%     -0.779500   -0.424250   -0.585750   -0.625000
# 50%     -0.165500    0.125500    0.036500    0.045000
# 75%      0.579250    0.719500    0.798250    0.721750
# max      2.927000    2.976000    2.581000    2.305000

# %%
df.iloc[:,30:40].describe()
# Out:
#                28          29          30          31          32          33  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean    -0
# count  250.000000  250.000000  250.000000  250.000000
# mean     0.045292   -0.038224    0.016220   -0.044704
# std      1.010267    1.033381    0.909847    1.033891
# min     -3.041000   -3.415000   -2.748000   -2.586000
# 25%     -0.606500   -0.696750   -0.627750   -0.776250
# 50%      0.040000   -0.010500    0.085000   -0.020000
# 75%      0.656500    0.703750    0.592000    0.687500
# max      2.813000    2.514000    2.701000    2.691000

# %%
df.iloc[:,50:60].describe()
# Out:
#                48          49          50          51          52          53  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean     0.085188    0.021192    0.031700    0.065468    0.047296   -0.051608
# std      0.984001    1.048054    0.988012    1.055504    1.033105    0.948249
# min     -2.677000   -2.760000   -2.582000   -2.553000   -2.736000   -3.559000
# 25%     -0.477000   -0.662250   -0.619000   -0.651250   -0.666750   -0.565500
# 50%      0.116000    0.085500    0.083000    0.049500    0.103500   -0.090500
# 75%      0.728250    0.729250    0.627000    0.811500    0.799250    0.550750
# max      2.902000    3.046000    2.983000    3.302000    2.313000    2.606000
#
#                54          55          56          57
# count  250.000000  250.000000  250.000000  250.000000
# mean     0.045292   -0.038224    0.016220   -0.044704
# std      1.010267    1.033381    0.909847    1.033891
# min     -3.041000   -3.415000   -2.748000   -2.586000
# 25%     -0.606500   -0.696750   -0.627750   -0.776250
# 50%      0.040000   -0.010500    0.085000   -0.020000
# 75%      0.656500    0.703750    0.592000    0.687500
# max      2.813000    2.514000    2.701000    2.691000

# %%
df.iloc[:,60:70].describe()
# Out:
#                58          59          60          61          62          63  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean     0.070112    0.047628    0.088100   -0.028832    0.034528    0.064612
# std      0.992619    1.053395    0.973836    0.968131    0.960685    0.924178
# min     -2.473000   -2.672000   -2.724000   -3.058000   -2.736000   -2.607000
# 25%     -0.547250   -0.713750   -0.473750   -0.680750   -0.596500   -0.510250
# 50%      0.016000   -0.034000    0.147000   -0.026000   -0.014000    0.080000
# 75%      0.703750    0.819000    0.750250    0.581750    0.741750    0.671500
# max      3.510000    2.800000    2.959000    2.479000    3.224000    2.767000
#
#                64          65          66          67
# count  250.000000  250.000000  250.000000  250.000000
# mean    -0.074768    0.003796   -0.114680    0.034240
# std      1.079216    0.983879    1.070762    0.993845
# min     -2.797000   -2.799000   -2.697000   -3.020000
# 25%     -0.889250   -0.636000   -0.796250   -0.604500
# 50%     -0.082000    0.022000   -0.101500   -0.034500
# 75%      0.721250    0.687000    0.644750    0.640750
# max      3.755000    3.163000    3.064000    2.785000

# %%
for i in range(60,290,10):
    print(df.iloc[:,i:i+10].describe())
# Out:
#                58          59          60          61          62          63  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean     0.070112    0.047628    0.088100   -0.028832    0.034528    0.064612
# std      0.992619    1.053395    0.973836    0.968131    0.960685    0.924178
# min     -2.473000   -2.672000   -2.724000   -3.058000   -2.736000   -2.607000
# 25%     -0.547250   -0.713750   -0.473750   -0.680750   -0.596500   -0.510250
# 50%      0.016000   -0.034000    0.147000   -0.026000   -0.014000    0.080000
# 75%      0.703750    0.819000    0.750250    0.581750    0.741750    0.671500
# max      3.510000    2.800000    2.959000    2.479000    3.224000    2.767000
#
#                64          65          66          67
# count  250.000000  250.000000  250.000000  250.000000
# mean    -0
\
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean     0.035696    0.034484   -0.066236   -0.057988    0.091556   -0.029896
# std      0.944743    1.023709    0.985451    0.951879    1.027877    0.966882
# min     -2.507000   -3.369000   -2.448000   -2.771000   -2.903000   -2.522000
# 25%     -0.624500   -0.653000   -0.786750   -0.701000   -0.543250   -0.672750
# 50%      0.045500   -0.023500   -0.101000   -0.109000    0.050500   -0.081500
# 75%      0.655750    0.634750    0.525750    0.612000    0.864000    0.630250
# max      2.832000    2.897000    3.753000    2.498000    2.725000    2.680000
#
#               274         275         276         277
# count  250.000000  250.000000  250.000000  250.000000
# mean     0.115648    0.007372    0.033552    0.090524
# std      1.037173    1.004543    1.006219    1.037119
# min     -2.759000   -2.915000   -2.618000   -3.623000
# 25%     -0.626750   -0.730250   -0.649750   -0.589500
# 50%      0.087500    0.035000    0.086500    0.126500
# 75%      0.836750    0.718000    0.791500    0.726000
# max      3.445000    2.846000    2.315000    2.780000
#               278         279         280         281         282         283  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean     0.001576   -0.007784    0.043184    0.082696    0.098476    0.055356
# std      1.024067    1.056086    1.012516    1.068741    0.934163    0.988100
# min     -2.673000   -3.229000   -2.537000   -2.748000   -2.850000   -2.577000
# 25%     -0.725750   -0.667750   -0.605000   -0.637750   -0.458250   -0.553500
# 50%      0.053500    0.063500    0.052500    0.103000    0.135500    0.039000
# 75%      0.688000    0.665750    0.603750    0.705500    0.688250    0.759000
# max      2.364000    2.908000    2.926000    3.441000    2.319000    2.842000
#
#               284         285         286         287
# count  250.000000  250.000000  250.000000  250.000000
# mean     0.111708   -0.015688    0.035992    0.026452
# std      1.043230    1.010720    1.058982    0.896318
# min     -2.973000   -2.709000   -3.605000   -2.357000
# 25%     -0.566750   -0.778250   -0.693250   -0.596750
# 50%      0.093500    0.014500   -0.007500    0.000500
# 75%      0.704750    0.673750    0.748750    0.604250
# max      3.343000    3.266000    3.061000    2.146000

# %%
X_train = df.iloc[:,2:]

# %%
X_train.shape
# We have 30 variables after creating our dummy variables for our categories
# Out:
# (250, 300)

# %%
#Improting the PCA module
from sklearn.decomposition import PCA
pca = PCA(svd_solver='randomized', random_state=42)

# %%
#Doing the PCA on the train data
pca.fit(X_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=42,
#   svd_solver='randomized', tol=0.0, whiten=False)

# %%
pca.components_
# Out:
# array([[-8.26932566e-02, -7.08928781e-03, -6.30503243e-02, ...,
#          6.54358351e-02, -8.39871840e-02, -1.21885481e-02],
#        [ 3.73425857e-02, -2.12998385e-02, -3.27300417e-02, ...,
#          6.34087950e-02,  4.61728182e-03,  5.10615698e-02],
#        [ 4.94448911e-02, -4.52356712e-02, -1.18554481e-01, ...,
#          3.50191997e-02,  3.58237078e-03, -7.28862137e-02],
#        ...,
#        [-6.64443356e-03,  1.00187971e-01,  9.98791605e-02, ...,
#          1.27656325e-03, -5.99155224e-02, -1.99823655e-02],
#        [-6.86243946e-05, -7.22973862e-02, -1.79747981e-02, ...,
#         -5.84233891e-03, -5.19689428e-02, -2.45111943e-02],
#        [-3.85722090e-02,  7.04183245e-02,  1.10678394e-01, ...,
#         -6.60730914e-02, -2.92473472e-02, -9.94047635e-02]])

# %%
colnames = list(X_train.columns)
pcs_df = pd.DataFrame({'PC1':pca.components_[0],'PC2':pca.components_[1], 'Feature':colnames})
#        2.54953990e-03, 2.52313495e-03, 2.47496325e-03, 2.41860931e-03,
#        2.38932065e-03, 2.35228416e-03, 2.32952140e-03, 2.31352343e-03,
#        2.29120915e-03, 2.24067564e-03, 2.19834343e-03, 2.14448530e-03,
#        2.13049644e-03, 2.09290627e-03, 2.00413021e-03, 1.98863486e-03,
#        1.97221959e-03, 1.95066534e-03, 1.91163281e-03, 1.88808499e-03,
#        1.85011379e-03, 1.80820497e-03, 1.72511092e-03, 1.71029727e-03,
#        1.67010620e-03, 1.64298074e-03, 1.62592378e-03, 1.58534102e-03,
#        1.56114588e-03, 1.51670907e-03, 1.49308766e-03, 1.48888389e-03,
#        1.47308399e-03, 1.41437204e-03, 1.38698539e-03, 1.36386119e-03,
#        1.34430113e-03, 1.31745129e-03, 1.30038253e-03, 1.26000178e-03,
#        1.22213863e-03, 1.21320564e-03, 1.19662866e-03, 1.14405763e-03,
#        1.12255923e-03, 1.10690767e-03, 1.08259777e-03, 1.06953703e-03,
#        1.05050005e-03, 1.00950127e-03, 9.98667795e-04, 9.77413605e-04,
#        9.23835121e-04, 9.06030024e-04, 8.99951466e-04, 8.76312268e-04,
#        8.64858383e-04, 8.32292455e-04, 8.24557993e-04, 8.17275066e-04,
#        7.84399746e-04, 7.62539951e-04, 7.35057743e-04, 7.14876889e-04,
#        7.03217335e-04, 6.85615150e-04, 6.74179578e-04, 6.62375727e-04,
#        6.40672787e-04, 6.28187532e-04, 6.01621617e-04, 5.93133280e-04,
#        5.71154863e-04, 5.45822637e-04, 5.37091696e-04, 5.23986262e-04,
#        5.12291939e-04, 4.83217832e-04, 4.64884481e-04, 4.57638026e-04,
#        4.35119740e-04, 4.20241938e-04, 4.16821925e-04, 4.03690994e-04,
#        3.98460983e-04, 3.70343769e-04, 3.48368505e-04, 3.44749312e-04,
#        3.32736764e-04, 3.13831728e-04, 3.00735410e-04, 2.90221432e-04,
#        2.65129711e-04, 2.56786908e-04, 2.46294236e-04, 2.39315755e-04,
#        2.26607380e-04, 2.08581643e-04, 1.95428274e-04, 1.84596896e-04,
#        1.80782468e-04, 1.74330540e-04, 1.58248303e-04, 1.43764385e-04,
#        1.34463294e-04, 1.16609442e-04, 1.13765613e-04, 1.05349927e-04,
#        9.54420850e-05, 8.46771946e-05, 8.10675048e-05, 7.40505242e-05,
#        6.88239100e-05, 6.59524841e-05, 5.92460457e-05, 5.04798800e-05,
#        4.31039135e-05, 1.42455695e-36])

# %%
#Making the screeplot - plotting the cumulative variance against the number of components
# %matplotlib inline
fig = plt.figure(figsize = (12,8))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
#Using incremental PCA for efficiency - saves a lot of time on larger datasets
from sklearn.decomposition import IncrementalPCA
pca_final = IncrementalPCA(n_components=150)

# %%
df_train_pca = pca_final.fit_transform(X_train)
df_train_pca.shape
# Out:
# (250, 150)

# %%
#creating correlation matrix for the principal components
corrmat = np.corrcoef(df_train_pca.transpose())

# %%
#plotting the correlation matrix
# %matplotlib inline
plt.figure(figsize = (20,10))
sns.heatmap(corrmat,annot = True)

# %%
# 1s -> 0s in diagonals
corrmat_nodiag = corrmat - np.diagflat(corrmat.diagonal())
print("max corr:",corrmat_nodiag.max(), ", min corr: ", corrmat_nodiag.min(),)
# we see that correlations are indeed very close to 0
# Out:
# max corr: 2.506295664409385e-15 , min corr:  -3.149879275202531e-15

# %%
y_train = df.iloc[:,[1]]

# %%
# Importing train-test-split 
from sklearn.model_selection import train_test_split

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, 
                                                    test_size=0.30, 
                                                    random_state = 99)

# %%
def plot_2d_space(X, y, label='Classes'):   
    colors = ['#1F77B4', '#FF7F0E']
    markers = ['o', 's']
    for l, c, m in zip(np.unique(y), colors, markers):
        plt.scatter(
            X[y==l, 0],
            X[y==l, 1],
            c=c, label=l, marker=m
        )
    plt.title(label)
    plt.legend(loc='upper right')
    plt.show()

# %%
#!pip install imblearn
import imblearn
import numpy as np
from imblearn.over_sampling import SMOTE

smote = SMOTE(ratio='minority')
X_sm, y_sm = smote.fit_sample(X_train,
                               y_train)

plot_2d_space(X_sm, y_sm, 'SMOTE over-sampling')
# Out:
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#!pip install imblearn
import imblearn
import numpy as np
from imblearn.over_sampling import SMOTE

smote = SMOTE(ratio='minority')
X_sm, y_sm = smote.fit_sample(X_train,
                               y_train)

plot_2d_space(X_sm, y_sm, 'SMOTE over-sampling')
# Out:
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
X_sm = pd.DataFrame(X_sm)

# %%
X_sm.shape
# Out:
# (234, 300)

# %%
y_sm = pd.DataFrame(y_sm)

# %%
y_sm.shape
# Out:
# (234, 1)

# %%
#Training the model on the train data
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

learner_pca = LogisticRegression()
model_pca = learner_pca.fit(X_sm,y_sm)
# Out:
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#Making prediction on the test data
pred_probs_test = model_pca.predict_proba(X_test)[:,1]
"{:2.2}".format(metrics.roc_auc_score(y_test, pred_probs_test))
# Out:
# '0.72'

# %%
len(pred_probs_test)
# Out:
# 75

# %%
Test = pd.read_csv("test.csv")

# %%
Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19750 entries, 0 to 19749
# Columns: 301 entries, id to 299
# dtypes: float64(300), int64(1)
# memory usage: 45.4 MB

# %%
PCA_test = Test.iloc[:,1:]

# %%
#Applying selected components to the test data - 16 components
df_test_pca = pca_final.transform(PCA_test)
df_test_pca.shape
# Out:
# (19750, 150)

# %%
#Making prediction on the test data
pred_probs_test = model_pca.predict_proba(df_test_pca)[:,1]
#"{:2.2}".format(metrics.roc_auc_score(y_test, pred_probs_test))

# %%
result = pd.DataFrame(pred_probs_test)

# %%
result.head()
# Out:
#           0
# 0  0.509138
# 1  0.478544
# 2  0.350796
# 3  0.971859
# 4  0.758332

# %%
submission = pd.concat([Test.iloc[:,0:1], result], axis =1)

# %%
submission.head()
# Out:
#     id         0
# 0  250  0.509138
# 1  251  0.478544
# 2  252  0.350796
# 3  253  0.971859
# 4  254  0.758332

# %%
# Creating new column 'predicted' with 1 if Churn_Prob>0.5 else 0
submission.iloc[:,1:2] = submission.iloc[:,1:2].apply(lambda x: x.map( lambda x: 1 if x > 0.5 else 0))

# %%
submission.to_csv("submission_predicted.csv")

# %%
# Importing decision tree classifier from sklearn library
from sklearn.tree import DecisionTreeClassifier

# Fitting the decision tree with default hyperparameters, apart from
# max_depth which is 5 so that we can plot and read the tree.
dt_default = DecisionTreeClassifier(max_depth=5)
dt_default.fit(X_sm, y_sm)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# Let's check the evaluation metrics of our default model

# Importing classification report and confusion matrix from sklearn metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Making predictions
y_pred_default = dt_default.predict(X_test)

# Printing classification report
print(classification_report(y_test, y_pred_default))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.56      0.49        32
#          1.0       0.58      0.44      0.50        43
#
#    micro avg       0.49      0.49      0.49        75
#    macro avg       0.50      0.50      0.49        75
# weighted avg       0.51      0.49      0.49        75

# %%
# Printing confusion matrix and accuracy
print(confusion_matrix(y_test,y_pred_default))
print(accuracy_score(y_test,y_pred_default))
# Out:
# [[18 14]
#  [24 19]]
# 0.49333333333333335

# %%
# GridSearchCV to find optimal max_depth
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV


# specify number of folds for k-fold CV
n_folds = 15

# parameters to build the model on
parameters = {'max_depth': range(1, 40)}

# instantiate the model
dtree = DecisionTreeClassifier(criterion = "gini", 
                               random_state = 100)

# fit tree on training data
tree = GridSearchCV(dtree, parameters, 
                    cv=n_folds, 
                   scoring="accuracy")
tree.fit(X_sm, y_sm)
# Out:
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=15, error_score='raise-deprecating',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best'),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'max_depth': range(1, 40)}, pre_dispatch='2*n_jobs',
#        refit=True, return_train_score='warn', scoring='accuracy',
#        verbose=0)

# %%
# scores of GridSearch CV
scores = tree.cv_results_
pd.DataFrame(scores).head(100)
# Out:
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split10_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split11_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split12_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split13_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split14_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split5_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split6_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split7_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split8_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split9_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0        0.007955         0.000936         0.700855          0.713670
# 1        0.013368         0.001072         0.619658          0.783581
# 2        0.029212         0.001262         0.688034          0.873317
# 3        0.031145         0.001266         0.696581          0.947793
# 4        0.026741         0.000871         0.696581          0.982299
# 5        0.035560         0.001000         0.700855          0.995115
# 6        0.029147         0.001072         0.692308          0.999085
# 7        0.048260         0.001406         0.692308          1.000000
# 8        0.056687         0.001738         0.692308          1.000000
# 9        0.039771         0.001140         0.692308          1.000000
# 10       0.044251         0.001404         0.692308          1.000000
# 11       0.045389         0.001339         0.692308          1.000000
# 12       0.051473         0.001469         0.692308          1.000000
# 13       0.036637         0.001337         0.692308          1.000000
# 14       0.029076         0.000867         0.692308          1.000000
# 15       0.037034         0.001206         0.692308          1.000000
# 16       0.034223         0.000870         0.692308          1.000000
# 17       0.048794         0.001802         0.692308          1.000000
# 18       0.051199         0.001538         0.692308          1.000000
# 19       0.029206         0.000938         0.692308          1.000000
# 20       0.056748         0.001607         0.692308          1.000000
# 21       0.036836         0.001134         0.692308          1.000000
# 22       0.046258         0.001204         0.692308          1.000000
# 23       0.041580         0.001204         0.692308          1.000000
# 24       0.038360         0.001075         0.692308          1.000000
# 25       0.030355         0.000803         0.692308          1.000000
# 26       0.038571         0.001268         0.692308          1.000000
# 27       0.049797         0.001405         0.692308          1.000000
# 28       0.031150         0.001069         0.692308          1.000000
# 29       0.032288         0.000870         0.692308          1.000000
# 30       0.039771         0.001269         0.692308          1.000000
# 31       0.031618         0.000999         0.692308          1.000000
# 32       0.033155         0.001070         0.692308          1.000000
# 33       0.039241         0.001204         0.692308          1.000000
# 34       0.028341         0.000932         0.692308          1.000000
# 35       0.029408         0.000936         0.692308          1.000000
# 36       0.028544         0.000869         0.692308          1.000000
# 37       0.038169         0.000936         0.692308          1.000000
# 38       0.036503         0.001133         0.692308          1.000000
#
#    param_max_depth             params  rank_test_score  split0_test_score  \
# 0                1   {'max_depth': 1}                1             0.7500
# 1                2   {'max_depth': 2}               39             0.6250
# 2                3   {'max_depth': 3}               38             0.9375
# 3                4   {'max_depth': 4}                3             0.9375
# 4                5   {'max_depth': 5}                3             0.8750
# 5                6   {'max_depth': 6}                1             0.8750
# 6                7   {'max_depth': 7}                5             0.8750
# 7                8   {'max_depth': 8}                5             0.8750
# 8                9   {'max_depth': 9}                5             0.8750
# 9               10  {'max_depth': 10}                5             0.8750
# 10              11  {'max_depth': 11}                5             0.8750
# 11              12  {'max_depth': 12}                5             0.8750
# 12              13  {'max_depth': 13}                5             0.8750
# 13              14  {'max_depth': 14}                5             0.8750
# 14              15  {'max_depth': 15}                5             0.8750
# 15              16  {'max_depth': 16}                5             0.8750
# 16              17  {'max_depth': 17}                5             0.8750
# 17              18  {'max_depth': 18}                5             0.8750
# 18              19  {'max_depth': 19}                5             0.8750
# 19              20  {'max_depth': 20}                5             0.8750
# 20              21  {'max_depth': 21}                5             0.8750
# 21              22  {'max_depth': 22}                5             0.8750
# 22              23  {'max_depth': 23}                5             0.8750
# 23              24  {'max_depth': 24}                5             0.8750
# 24              25  {'max_depth': 25}                5             0.8750
# 25              26  {'max_depth': 26}                5             0.8750
# 26              27  {'max_depth': 27}                5             0.8750
# 27              28  {'max_depth': 28}                5             0.8750
# 28              29  {'max_depth': 29}                5             0.8750
# 29              30  {'max_depth': 30}                5             0.8750
# 30              31  {'max_depth': 31}                5             0.8750
# 31              32  {'max_depth': 32}                5             0.8750
# 32              33  {'max_depth': 33}                5             0.8750
# 33              34  {'max_depth': 34}                5             0.8750
# 34              35  {'max_depth': 35}                5             0.8750
# 35              36  {'max_depth': 36}                5             0.8750
# 36              37  {'max_depth': 37}                5             0.8750
# 37              38  {'max_depth': 38}                5             0.8750
# 38              39  {'max_depth': 39}                5             0.8750
#
#     split0_train_score  split10_test_score       ...         \
# 0             0.711009              0.6875       ...
# 1             0.793578              0.6250       ...
# 2             0.848624              0.6875       ...
# 3             0.935780              0.6875       ...
# 4             0.977064              0.6875       ...
# 5             0.990826              0.6875       ...
# 6             1.000000              0.6875       ...
# 7             1.000000              0.6875       ...
# 8             1.000000              0.6875       ...
# 9             1.000000              0.6875       ...
# 10            1.000000              0.6875       ...
# 11            1.000000              0.6875       ...
# 12            1.000000              0.6875       ...
# 13            1.000000              0.6875       ...
# 14            1.000000              0.6875       ...
# 15            1.000000              0.6875       ...
# 16            1.000000              0.6875       ...
# 17            1.000000              0.6875       ...
# 18            1.000000              0.6875       ...
# 19            1.000000              0.6875       ...
# 20            1.000000              0.6875       ...
# 21            1.000000              0.6875       ...
# 22            1.000000              0.6875       ...
# 23            1.000000              0.6875       ...
# 24            1.000000              0.6875       ...
# 25            1.000000              0.6875       ...
# 26            1.000000              0.6875       ...
# 27            1.000000              0.6875       ...
# 28            1.000000              0.6875       ...
# 29            1.000000              0.6875       ...
# 30            1.000000              0.6875       ...
# 31            1.000000              0.6875       ...
# 32            1.000000              0.6875       ...
# 33            1.000000              0.6875       ...
# 34            1.000000              0.6875       ...
# 35            1.000000              0.6875       ...
# 36            1.000000              0.6875       ...
# 37            1.000000              0.6875       ...
# 38            1.000000              0.6875       ...
#
#     split7_test_score  split7_train_score  split8_test_score  \
# 0              0.6250            0.720183             0.6875
# 1              0.5625            0.802752             0.6250
# 2              0.5625            0.885321             0.5625
# 3              0.7500            0.940367             0.5000
# 4              0.6250            0.972477             0.5625
# 5              0.6250            0.990826             0.5625
# 6              0.6250            0.995413             0.5625
# 7              0.6250            1.000000             0.5625
# 8              0.6250            1.000000             0.5625
# 9              0.6250            1.000000             0.5625
# 10             0.6250            1.000000             0.5625
# 11             0.6250            1.000000             0.5625
# 12             0.6250            1.000000             0.5625
# 13             0.6250            1.000000             0.5625
# 14             0.6250            1.000000             0.5625
# 15             0.6250            1.000000             0.5625
# 16             0.6250            1.000000             0.5625
# 17             0.6250            1.000000             0.5625
# 18             0.6250            1.000000             0.5625
# 19             0.6250            1.000000             0.5625
# 20             0.6250            1.000000             0.5625
# 21             0.6250            1.000000             0.5625
# 22             0.6250            1.000000             0.5625
# 23             0.6250            1.000000             0.5625
# 24             0.6250            1.000000             0.5625
# 25             0.6250            1.000000             0.5625
# 26             0.6250            1.000000             0.5625
# 27             0.6250            1.000000             0.5625
# 28             0.6250            1.000000             0.5625
# 29             0.6250            1.000000             0.5625
# 30             0.6250            1.000000             0.5625
# 31             0.6250            1.000000             0.5625
# 32             0.6250            1.000000             0.5625
# 33             0.6250            1.000000             0.5625
# 34             0.6250            1.000000             0.5625
# 35             0.6250            1.000000             0.5625
# 36             0.6250            1.000000             0.5625
# 30        0.000576        0.128354         0.000000
# 31        0.000367        0.128354         0.000000
# 32        0.000444        0.128354         0.000000
# 33        0.000400        0.128354         0.000000
# 34        0.000249        0.128354         0.000000
# 35        0.000250        0.128354         0.000000
# 36        0.000341        0.128354         0.000000
# 37        0.000575        0.128354         0.000000
# 38        0.000721        0.128354         0.000000
#
# [39 rows x 41 columns]

# %%
# GridSearchCV to find optimal max_depth
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV


# specify number of folds for k-fold CV
n_folds = 15

# parameters to build the model on
parameters = {'min_samples_leaf': range(5, 200, 20)}

# instantiate the model
dtree = DecisionTreeClassifier(criterion = "gini", 
                               random_state = 100)

# fit tree on training data
tree = GridSearchCV(dtree, parameters, 
                    cv=n_folds, 
                   scoring="accuracy")
tree.fit(X_sm, y_sm)
# Out:
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=15, error_score='raise-deprecating',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best'),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'min_samples_leaf': range(5, 200, 20)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
# scores of GridSearch CV
scores = tree.cv_results_
pd.DataFrame(scores).head()
# Out:
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split10_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split11_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split12_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split13_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split14_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split5_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split6_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split7_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split8_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split9_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#    mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0       0.025336         0.000935         0.679487          0.937139
# 1       0.019718         0.001073         0.594017          0.782991
# 2       0.012228         0.000742         0.670940          0.715796
# 3       0.012297         0.001540         0.700855          0.713670
# 4       0.006280         0.000867         0.700855          0.713670
#
#   param_min_samples_leaf                    params  rank_test_score  \
# 0                      5   {'min_samples_leaf': 5}                4
# 1                     25  {'min_samples_leaf': 25}                6
# 2                     45  {'min_samples_leaf': 45}                5
# 3                     65  {'min_samples_leaf': 65}                1
# 4                     85  {'min_samples_leaf': 85}                1
#
#    split0_test_score  split0_train_score  split10_test_score       ...         \
# 0              0.750            0.935780              0.6250       ...
# 1              0.625            0.770642              0.6250       ...
# 2              0.750            0.711009              0.6875       ...
# 3              0.750            0.711009              0.6875       ...
# 4              0.750            0.711009              0.6875       ...
#
#    split7_test_score  split7_train_score  split8_test_score  \
# 0             0.7500            0.917431             0.5000
# 1             0.4375            0.770642             0.5625
# 2             0.6250            0.720183             0.6875
# 3             0.6250            0.720183             0.6875
# 4             0.6250            0.720183             0.6875
#
#    split8_train_score  split9_test_score  split9_train_score  std_fit_time  \
# 0            0.949541              0.750            0.944954      0.002055
# 1            0.821101              0.625            0.816514      0.006798
# 2            0.715596              0.625            0.720183      0.003977
# 3            0.715596              0.625            0.720183      0.004825
# 4            0.715596              0.625            0.720183      0.000674
#
#    std_score_time  std_test_score  std_train_score
# 0        0.000250        0.109055         0.012230
# 1        0.000575        0.101188         0.019415
# 2        0.000578        0.095533         0.007682
# 3        0.000890        0.093211         0.006170
# 4        0.000500        0.093211         0.006170
#
# [5 rows x 41 columns]

# %%
# plotting accuracies with min_samples_leaf
plt.figure()
plt.plot(scores["param_min_samples_leaf"], 
         scores["mean_train_score"], 
         label="training accuracy")
plt.plot(scores["param_min_samples_leaf"], 
         scores["mean_test_score"], 
         label="test accuracy")
plt.xlabel("min_samples_leaf")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
# GridSearchCV to find optimal min_samples_split
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV


# specify number of folds for k-fold CV
n_folds = 5

# parameters to build the model on
parameters = {'min_samples_split': range(5, 200, 20)}

# instantiate the model
dtree = DecisionTreeClassifier(criterion = "gini", 
                               random_state = 100)

# fit tree on training data
tree = GridSearchCV(dtree, parameters, 
                    cv=n_folds, 
                   scoring="accuracy")
tree.fit(X_sm, y_sm)
# Out:
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best'),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'min_samples_split': range(5, 200, 20)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
# scores of GridSearch CV
scores = tree.cv_results_
pd.DataFrame(scores).head(10)
# Out:
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#    mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 0       0.025267         0.001409         0.692308          0.996809
# 1       0.023644         0.000614         0.675214          0.927477
# 2       0.022659         0.001002         0.641026          0.901784
# 3       0.023267         0.000802         0.623932          0.869721
# 4       0.015638         0.000599         0.628205          0.822809
# 5       0.008428         0.000601         0.679487          0.741615
# 6       0.014447         0.001602         0.675214          0.734088
# 7       0.019453         0.002006         0.675214          0.722260
# 8       0.019451         0.002607         0.666667          0.702906
# 9       0.006617         0.001004         0.666667          0.702906
#
#   param_min_samples_split                      params  rank_test_score  \
# 0                       5    {'min_samples_split': 5}                1
# 1                      25   {'min_samples_split': 25}                3
# 2                      45   {'min_samples_split': 45}                8
# 3                      65   {'min_samples_split': 65}               10
# 4                      85   {'min_samples_split': 85}                9
# 5                     105  {'min_samples_split': 105}                2
# 6                     125  {'min_samples_split': 125}                3
# 7                     145  {'min_samples_split': 145}                3
# 8                     165  {'min_samples_split': 165}                6
# 9                     185  {'min_samples_split': 185}                6
#
#    split0_test_score  split0_train_score  split1_test_score       ...         \
# 0           0.583333            1.000000           0.645833       ...
# 1           0.520833            0.946237           0.687500       ...
# 2           0.458333            0.908602           0.666667       ...
# 3           0.395833            0.838710           0.666667       ...
# 4           0.479167            0.806452           0.666667       ...
# 5           0.687500            0.715054           0.625000       ...
# 6           0.687500            0.715054           0.604167       ...
# 7           0.687500            0.715054           0.604167       ...
# 8           0.687500            0.715054           0.562500       ...
# 9           0.687500            0.715054           0.562500       ...
#
#    split2_test_score  split2_train_score  split3_test_score  \
# 0           0.695652            0.994681           0.826087
# 1           0.673913            0.914894           0.782609
# 2           0.673913            0.914894           0.782609
# 3           0.652174            0.898936           0.826087
# 4           0.673913            0.808511           0.717391
# 5           0.695652            0.718085           0.739130
# 6           0.695652            0.718085           0.739130
# 7           0.695652            0.718085           0.739130
# 8           0.695652            0.718085           0.739130
# 9           0.695652            0.718085           0.739130
#
#    split3_train_score  split4_test_score  split4_train_score  std_fit_time  \
# 0            1.000000           0.717391            0.989362      0.002027
# 1            0.888298           0.717391            0.920213      0.003664
# 2            0.888298           0.630435            0.867021      0.003782
# 3            0.845745           0.586957            0.835106      0.005280
# 4            0.792553           0.608696            0.792553      0.006550
# 5            0.707447           0.652174            0.723404      0.004340
# 6            0.707447           0.652174            0.723404      0.006128
# 7            0.707447           0.652174            0.723404      0.003208
# 8            0.707447           0.652174            0.723404      0.003635
# 9            0.707447           0.652174            0.723404      0.001217
#
#    std_score_time  std_test_score  std_train_score
# 0    4.975860e-04        0.080766         0.004255
# 1    5.014300e-04        0.086817         0.027274
# 2    9.488940e-07        0.105625         0.021959
# 3    7.496155e-04        0.139665         0.038039
# 4    4.893176e-04        0.083120         0.046075
# 5    4.907602e-04        0.038981         0.051495
# 6    4.907365e-04        0.045343         0.036548
# 7    8.988975e-04        0.045343         0.013548
# 8    4.922330e-04        0.059611         0.026688
# 9    6.503192e-07        0.059611         0.026688
#
# [10 rows x 21 columns]

# %%
# plotting accuracies with min_samples_leaf
plt.figure()
plt.plot(scores["param_min_samples_split"], 
         scores["mean_train_score"], 
         label="training accuracy")
plt.plot(scores["param_min_samples_split"], 
         scores["mean_test_score"], 
         label="test accuracy")
plt.xlabel("min_samples_split")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# C:\Users\SharmilaK1\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
# model with optimal hyperparameters
clf_gini = DecisionTreeClassifier(criterion = "gini", 
                                  random_state = 100,
                                  max_depth=1, 
                                  min_samples_leaf=65,
                                  min_samples_split=5)
clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=65, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best')

# %%
# Making predictions
y_pred_default = clf_gini.predict(X_test)

# Printing classification report
print(classification_report(y_test, y_pred_default))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.72      0.61        32
#          1.0       0.72      0.53      0.61        43
#
#    micro avg       0.61      0.61      0.61        75
#    macro avg       0.63      0.63      0.61        75
# weighted avg       0.64      0.61      0.61        75

# %%
# Printing confusion matrix and accuracy
print(confusion_matrix(y_test,y_pred_default))
print(accuracy_score(y_test,y_pred_default))
# Out:
# [[23  9]
#  [20 23]]
# 0.6133333333333333

# %%
y_pred = clf_gini.predict_proba(PCA_test)

# %%
result = pd.DataFrame(pred_probs_test)

# %%
submission = pd.concat([Test.iloc[:,0:1], result], axis =1)

# %%
# Creating new column 'predicted' with 1 if Churn_Prob>0.5 else 0
submission.iloc[:,1:2] = submission.iloc[:,1:2].apply(lambda x: x.map( lambda x: 1 if x > 0.7 else 0))

# %%
submission.to_csv("submissions_predicted.csv")
